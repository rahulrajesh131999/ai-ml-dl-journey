# %% [markdown]
# If we are dealing with images, voices, large amount of text it is better to use Neural Nets

# %% [markdown]
# If the no of dimentions are really high, like about 100k or millions, then its better to use linear models
