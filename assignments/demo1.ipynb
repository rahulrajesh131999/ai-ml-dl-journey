# %%
import numpy as np
import pandas as pd

pd.set_option("display.max.columns",100)
# %matplotlib inline

import warnings

import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings("ignore")

# %%
DATA_URL = "https://raw.githubusercontent.com/Yorko/mlcourse.ai/main/data/"

data = pd.read_csv(DATA_URL + "adult.data.csv")
data.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
#  1. How many men and women (sex feature) are represented in this dataset?

# %%
data["sex"].value_counts()
# Out:
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64

# %% [markdown]
# 2. What is the average age (age feature) of women?

# %%
data[data["sex"] == "Female"]["age"].mean()
# Out:
# np.float64(36.85823043357163)

# %% [markdown]
# 3. What is the percentage of German citizens (native-country feature)?

# %%
#data["native-country"].value_counts(normalize=True) * 100
(data["native-country"] == "Germany").sum()/data.shape[0]
# Out:
# np.float64(0.004207487485028101)

# %% [markdown]
# 4-5. What are the mean and standard deviation of age for those who earn more than 50K per year (salary feature) and those who earn less than 50K per year?

# %%
#4 more than 50K 
data["salary"].unique()
a = data[data["salary"] == "<=50K"]["age"].describe()
#print(a.mean())
print(a)
# Out:
# count    24720.000000
# mean        36.783738
# std         14.020088
# min         17.000000
# 25%         25.000000
# 50%         34.000000
# 75%         46.000000
# max         90.000000
# Name: age, dtype: float64

# %%
#5 less than 50K 
a = data[data["salary"] == ">50K"]["age"].describe()
#print(a.mean())
print(a)
# Out:
# count    7841.000000
# mean       44.249841
# std        10.519028
# min        19.000000
# 25%        36.000000
# 50%        44.000000
# 75%        51.000000
# max        90.000000
# Name: age, dtype: float64

# %% [markdown]
# 6. Is it true that people who earn more than 50K have at least high school education? (education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters or Doctorate feature)

# %%
data["education"].unique()

data[data["salary"] == ">50K"]["education"].value_counts()
# Out:
# education
# Bachelors       2221
# HS-grad         1675
# Some-college    1387
# Masters          959
# Prof-school      423
# Assoc-voc        361
# Doctorate        306
# Assoc-acdm       265
# 10th              62
# 11th              60
# 7th-8th           40
# 12th              33
# 9th               27
# 5th-6th           16
# 1st-4th            6
# Name: count, dtype: int64

# %% [markdown]
# 7. Display age statistics for each race (race feature) and each gender (sex feature). Use groupby() and describe(). Find the maximum age of men of Amer-Indian-Eskimo race.

# %%
#data.groupby(["race"])["age"].describe()
for (race, sex), sub_df in data.groupby(["race", "sex"]):
    print("Race: {0}, sex: {1}".format(race, sex))
    print(sub_df["age"].describe())
# Out:
# Race: Amer-Indian-Eskimo, sex: Female
# count    119.000000
# mean      37.117647
# std       13.114991
# min       17.000000
# 25%       27.000000
# 50%       36.000000
# 75%       46.000000
# max       80.000000
# Name: age, dtype: float64
# Race: Amer-Indian-Eskimo, sex: Male
# count    192.000000
# mean      37.208333
# std       12.049563
# min       17.000000
# 25%       28.000000
# 50%       35.000000
# 75%       45.000000
# max       82.000000
# Name: age, dtype: float64
# Race: Asian-Pac-Islander, sex: Female
# count    346.000000
# mean      35.089595
# std       12.300845
# min       17.000000
# 25%       25.000000
# 50%       33.000000
# 75%       43.750000
# max       75.000000
# Name: age, dtype: float64
# Race: Asian-Pac-Islander, sex: Male
# count    693.000000
# mean      39.073593
# std       12.883944
# min       18.000000
# 25%       29.000000
# 50%       37.000000
# 75%       46.000000
# max       90.000000
# Name: age, dtype: float64
# Race: Black, sex: Female
# ...

# %% [markdown]
# 8. Among whom is the proportion of those who earn a lot (>50K) greater: married or single men (marital-status feature)? Consider as married those who have a marital-status starting with Married (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), the rest are considered bachelors.

# %%
#married
data[(data["sex"] == "Male") & (data["marital-status"].str.startswith("Married"))]["salary"].value_counts(normalize=True) * 100
# Out:
# salary
# <=50K    55.948601
# >50K     44.051399
# Name: proportion, dtype: float64

# %%
#single

data[(data["sex"] == "Male")& ~(data["marital-status"].str.startswith("Married"))]["salary"].value_counts(normalize=True)
# Out:
# salary
# <=50K    0.915505
# >50K     0.084495
# Name: proportion, dtype: float64

# %% [markdown]
# 9. What is the maximum number of hours a person works per week (hours-per-week feature)? How many people work such a number of hours, and what is the percentage of those who earn a lot (>50K) among them?

# %%
data["hours-per-week"].value_counts()
data.sort_values(by=["hours-per-week"],ascending=False)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 25354   65           Private   89681       Masters             14
# 29751   51  Self-emp-not-inc   32372          12th              8
# 8796    39           Private   70995     Bachelors             13
# 21147   39           Private  348521  Some-college             10
# 25806   49                 ?   31478       7th-8th              4
# ...    ...               ...     ...           ...            ...
# 9147    75                 ?  260543          10th              6
# 23536   69                 ?  320280  Some-college             10
# 19337   72                 ?   76860       HS-grad              9
# 8447    67                 ?  244122     Assoc-voc             11
# 32525   81                 ?  120478     Assoc-voc             11
#
#            marital-status        occupation    relationship  \
# 25354       Never-married    Prof-specialty   Not-in-family
# ...

# %%
data[data["hours-per-week"] == 99].value_counts(normalize=True)
data.pivot_table(["hours-per-week"],["salary"],aggfunc="mean")
# Out:
#         hours-per-week
# salary
# <=50K        38.840210
# >50K         45.473026
