# %% [markdown]
# STL decomposition

# %% [markdown]
# resuduals - error, that is y - y^
# residual values should not be correlitated with each other
# a model will be ideal if the residual is just white noise
#
# #### Testing the error
#
# - unbisedness - Wilcoxon test
# - stationary - visual analysis, KPSS test
# - uncorrelatedness - correlogram, Ljunb-Box test
# - normality - q-q plot, Shapiro-wilk test

# %% [markdown]
# #### Variance stablising transform

# %%
SARIMAX, regARIMA

# %% [markdown]
# auto.arima
